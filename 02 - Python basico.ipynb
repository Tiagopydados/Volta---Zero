# %% [markdown]
# ### 01 - Teste de gravidez
# Escreva uma célula com controle de fluxos que tem como premissa a existência das seguintes variáveis:
#
# - ```sexo``` como ```str``` indicando os valores '**M**' para masculino e '**F**' para feminino
# - ```beta_hcg``` que indica a quantidade do beta-HCG no sangue em mUI/mL.
#
# A sua tarefa é escrever um código que imprima como resultado "indivíduo do sexo masculino" quando sexo = 'M', caso sexo = 'F', se o valor de beta-HCG for maior que 5, retorne "Positivo" indicando que a paciente está grávida, e retorne "Negativo" caso contrário.
#
# Não mexa nos valores da variável ```sexo``` nem em ```beta_hcg```, e escreva um código que funcione para quaisquer valores possíveis de ambos: ```sexo``` = '**M**' ou '**F**' e ```beta_hcg``` assumindo valores inteiros positivos.

# %%
sexo = 'M'
beta_hcg = 0

# seu código vem abaixo desta linha
if sexo == 'M':
  print("indivíduo do sexo masculino")

elif sexo == 'F' and beta_hcg >= 5:
  print("Positivo")

else:
  print("Negativo")
# Out:
# indivíduo do sexo masculino

# %% [markdown]
# ### 02 - Renomeando variáveis
#
# Vamos ver adiante que uma forma de renomear variáveis de um conjunto de dados é através de dicionários - o dicionário deve conter como chave o nome original, associando a cada chave um único valor (tipo *str*) que contenha o nome novo.
#
# A sua tarefa é escrever um dicionário que possa ser utilizado para traduzir as variáveis ```name``` (nome), ```age``` (idade) e ```income``` (renda). Ou seja, esse dicionário deve relacionar as chaves *name, age* e *income* às suas respectivas traduções.

# %%
dic_renomeacao = {'name': 'nome',
                  'age':'idade',
                  'income':'renda'}
dic_renomeacao
# Out:
# {'name': 'nome', 'age': 'idade', 'income': 'renda'}

# %% [markdown]
# ### 03 - É divisível?
# A sua tarefa é escrever um código que indique se um número ```N``` é divisível por um número P. Escreva um programa que faça essa verificação para quaisquer combinações de ```N``` e ```M``` e devolva uma mensagem indicativa no output.

# %%
N = 42
M = 7


#Seu código
if N % M == 0:
  print("É divizivel!")

else:
  print("Não é divizivel!")
# Out:
# É divizivel!

# %% [markdown]
# ### 04 - Números primos
# > Um número **N** é primo se e somente se é divisível por 1, -1, por **N** e por -**N**.
#
# Escreva um script que verifica se ```N``` é um número primo, verificando se ```N``` é divisível por todos os números de ```1``` a ```N-1```. Você vai precisar usar alguma ferramenta de *loop* que você aprendeu para isto. No final, devolva uma mensagem no output indicando se o número é primo ou não.

# %%
N = 47

# seu código abaixo
P = 1

while P <= N-1:
  if N % P == 0:
    print(f"O numero {P} é divisivel.")
  else:
    print(f"O numero {P} não é divisivel.")
  P += 1

print(f"\nO numero {N} é primo!")
# Out:
# O numero 1 é divisivel.
# O numero 2 não é divisivel.
# O numero 3 não é divisivel.
# O numero 4 não é divisivel.
# O numero 5 não é divisivel.
# O numero 6 não é divisivel.
# O numero 7 não é divisivel.
# O numero 8 não é divisivel.
# O numero 9 não é divisivel.
# O numero 10 não é divisivel.
# O numero 11 não é divisivel.
# O numero 12 não é divisivel.
# O numero 13 não é divisivel.
# O numero 14 não é divisivel.
# O numero 15 não é divisivel.
# O numero 16 não é divisivel.
# O numero 17 não é divisivel.
# O numero 18 não é divisivel.
# O numero 19 não é divisivel.
# O numero 20 não é divisivel.
# O numero 21 não é divisivel.
# O numero 22 não é divisivel.
# O numero 23 não é divisivel.
# O numero 24 não é divisivel.
# O numero 25 não é divisivel.
# O numero 26 não é divisivel.
# O numero 27 não é divisivel.
# O numero 28 não é divisivel.
# O numero 29 não é divisivel.
# O numero 30 não é divisivel.
# O numero 31 não é divisivel.
# O numero 32 não é divisivel.
# O numero 33 não é divisivel.
# O numero 34 não é divisivel.
# O numero 35 não é divisivel.
# O numero 36 não é divisivel.
# O numero 37 não é divisivel.
# O numero 38 não é divisivel.
# O numero 39 não é divisivel.
# O numero 40 não é divisivel.
# O numero 41 não é divisivel.
# O numero 42 não é divisivel.
# O numero 43 não é divisivel.
# O numero 44 não é divisivel.
# O numero 45 não é divisivel.
# O numero 46 não é divisivel.
#
# O numero 47 é primo!

# %% [markdown]
# ### 05 - Desafio
# O algorítmo do exercício anterior não é o mais eficiente. O que você pode fazer para deixá-lo mais eficiente? Ou seja, executar menos comparações, portanto consumir menos tempo.
# 1. Será que precisamos correr o loop até o final sempre?
# 2. Será que precisamos mesmo verificar **todos** os números?
# 3. Será que precisamos ir até N-1?
#
# Essas perguntas levam ao tipo de pensamento voltado a deixar um algoritmo mais eficiente. Veja se você consegue melhorar o seu.

# %%
N = 98

# seu código aqui
primo = True
P = 2

while P < N:
    if N % P == 0:
        primo = False
        break
    P += 1

if primo == True and N > 1:
    print(f"O número {N} é primo!")
else:
    print(f"O número {N} não é primo.")
# Out:
# O número 98 não é primo.

# %% [markdown]
# ### 06 - Peso ideal 1
# O IMC (índice de massa corpórea) é um indicador de saúde mais bem aceito que o peso. Ele é calculado como:
#
# $$ IMC = \dfrac{peso}{altura^2}$$
#
# Segundo a OMS, valores *normais* são entre 18.5 e 24.9.
#
# Sua tarefa é encontrar o ponto médio dessa faixa.

# %%
imc_ideal = (18.5 + 24.9) / 2
imc_ideal
# Out:
# 21.7

# %% [markdown]
# ### 07 - Peso ideal 2
# Recebendo um valor de altura, encontre o peso '*ideal*' dessa pessoa, que fornece o IMC encontrado acima

# %%
altura = 1.70

# Seu código
peso_ideal = altura ** 2 * 21.7
peso_ideal
# Out:
# 62.712999999999994

# %% [markdown]
# ### 08 - Peso ideal 3
# Dada uma lista contendo as alturas de pacientes, crie uma nova lista que contenha o peso '*ideal*' (que fornece o IMC calculado em **Peso ideal 1**) desses pacientes.

# %%
lista_alturas = [1.95, 2.05, 1.70, 1.65]

lista_peso_ideal = []

# seu código
for x in lista_alturas:
    calculo = x ** 2 * 21.7
    lista_peso_ideal.append(calculo)



lista_peso_ideal
# Out:
# [82.51424999999999, 91.19425, 62.712999999999994, 59.07824999999999]

# %% [markdown]
# ### 09 - Peso ideal 4
# Dada uma lista de tuplas - cada elemento da lista é uma tupla contendo altura e peso de um paciente - crie uma nova lista com o IMC desses pacientes.

# %%
altura_peso = [(1.80, 90), (1.65, 75), (1.91, 70)]

imc = []

# seu código
for x in altura_peso:
    calculo = x[1] / x[0] ** 2
    imc.append(calculo)


imc
# Out:
# [27.777777777777775, 27.548209366391188, 19.188070502453332]

# %% [markdown]
# ### 10 - Peso ideal 5
# Dada uma lista de **listas** - cada elemento da lista é uma **lista** contendo altura e peso de um paciente, adicione mais um elemento à lista de cada paciente contendo o IMC do paciente. Verifique também se é 'baixo', 'normal' ou 'alto' segundo os padrões da OMS em que normal é entre 18.5 e 24.9.
#
# Reflexão: por que no problema anterior temos que criar uma nova lista, e não podemos adicionar os dados de cada indivíduo à tupla?

# %%
altura_peso = [[1.80, 90], [1.65, 75], [1.91, 70]]

# Seu código
for x in altura_peso:
    calculo = x[1] / x[0] ** 2
    x.append(calculo)

print(altura_peso)

for y in altura_peso:
  if y[2] > 24.9:
    y.append("Alto")
  elif y[2] < 18.5:
    y.append("Baixo")
  else:
    y.append("Normal")
print(f"\n{altura_peso}")
# Out:
# [[1.8, 90, 27.777777777777775], [1.65, 75, 27.548209366391188], [1.91, 70, 19.188070502453332]]
#
# [[1.8, 90, 27.777777777777775, 'Alto'], [1.65, 75, 27.548209366391188, 'Alto'], [1.91, 70, 19.188070502453332, 'Normal']]
